# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
[]
data = [[2,0,81],[4,4,93],[6,2,91],[8,3,97]]
x1 = [i[0] for i in data]
x2 = [i[1] for i in data]
y = [i[2] for i in data]

ax = plt.axes(projection = '3d')
ax.set_xlabel('study hours')
ax.set_ylabel('private_class')
ax.set_zlabel('Score')
ax.dist = 11
ax.scatter(x1,x2,y)
plt.show()

x1_data = np.array(x1)
x2_data = np.array(x2)
y_data = np.array(y)

#기울기와 절편 초기화
a1 = 0
a2 = 0
b = 0

#학습률
lr = 0.05

epochs = 2001

for i in range(epochs) :
    y_pred = a1*x1_data + a2*x2_data +b
    error = y_pred - y_data #씨발 이게 문제였구나
    
    a1_diff = (1/len(x1_data)) * sum(x1_data * (error))
    a2_diff = (1/len(x2_data)) * sum(x2_data * (error))
    b_diff = (1/len(x1_data)) * sum(error)
    
    a1 = a1 - lr*a1_diff
    a2 = a2 - lr*a2_diff
    b = b - lr*b_diff
    
    if i % 100 == 0:
        print("epoch : {}, 기울기1 = {}, 기울기 2 = {}, 절편 = {} ".format(i,a1,a2,b))
# Out:
# epoch : 0, 기울기1 = 23.200000000000003, 기울기 2 = 10.5625, 절편 = 4.525
# epoch : 100, 기울기1 = 6.434805446608685, 기울기 2 = 3.98925524892891, 절편 = 43.97569356791496
# epoch : 200, 기울기1 = 3.7255348759847924, 기울기 2 = 3.0541408134809784, 절편 = 62.576629969168025
# epoch : 300, 기울기1 = 2.503714679287745, 기울기 2 = 2.6322742530634486, 절편 = 70.96564181265175
# epoch : 400, 기울기1 = 1.952674645725859, 기울기 2 = 2.4420125981800993, 절편 = 74.74908051776274
# epoch : 500, 기울기1 = 1.7041559609856545, 기울기 2 = 2.356204719590433, 절편 = 76.45540883097016
# epoch : 600, 기울기1 = 1.592074201194008, 기울기 2 = 2.31750542401674, 절편 = 77.22496175342586
# epoch : 700, 기울기1 = 1.5415254028566499, 기울기 2 = 2.300052067722291, 절편 = 77.57202960424704
# epoch : 800, 기울기1 = 1.5187279287796718, 기울기 2 = 2.292180615763661, 절편 = 77.7285569717077
# epoch : 900, 기울기1 = 1.5084462832928398, 기울기 2 = 2.28863059622062, 절편 = 77.79915070923249
# epoch : 1000, 기울기1 = 1.5038092680884374, 기울기 2 = 2.2870295397926297, 절편 = 77.83098843741102
# epoch : 1100, 기울기1 = 1.5017179773477205, 기울기 2 = 2.286307464419652, 절편 = 77.84534723142188
# epoch : 1200, 기울기1 = 1.500774806629192, 기울기 2 = 2.285981808911738, 절편 = 77.85182303787037
# epoch : 1300, 기울기1 = 1.5003494372690325, 기울기 2 = 2.28583493849654, 절편 = 77.85474362222634
# epoch : 1400, 기울기1 = 1.5001575959734832, 기울기 2 = 2.2857687000379943, 절편 = 77.85606080380799
# epoch : 1500, 기울기1 = 1.5000710756781244, 기울기 2 = 2.285738826537708, 절편 = 77.85665485181606
# epoch : 1600, 기울기1 = 1.5000320550830635, 기울기 2 = 2.2857253536091546, 절편 = 77.85692276706845
# epoch : 1700, 기울기1 = 1.500014456820917, 기울기 2 = 2.2857192773274324, 절편 = 77.85704359666722
# epoch : 1800, 기울기1 = 1.5000065200165227, 기울기 2 = 2.285716536928462, 절편 = 77.85709809073502
# epoch : 1900, 기울기1 = 1.500002940523069, 기울기 2 = 2.2857153010103657, 절편 = 77.85712266752303
# epoch : 2000, 기울기1 = 1.5000013261739265, 기울기 2 = 2.2857147436121346, 절편 = 77.85713375163787
